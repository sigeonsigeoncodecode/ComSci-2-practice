# %% [markdown]
# <a href="https://colab.research.google.com/github/sigeonsigeoncodecode/ComSci-2-practice/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ask the user to input a number
num = int(input("Enter a number: "))

#check if the number is even or odd
if num % 2 == 0:
   print(f"The number {num} is even.")
else:
   print(f"The number {num} is odd.")
# Out:
# Enter a number: 19
# The number 19 is odd.
